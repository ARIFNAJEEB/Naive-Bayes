# %%
import pandas as pd
import seaborn as sns

# %%
test=pd.read_csv('SalaryData_Test.csv')
test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
sns.pairplot(test)

# %%
sns.boxplot(test)
# Out:
# <Axes: >

# %%
sns.barplot(test)
# Out:
# <Axes: >

# %%
from sklearn.naive_bayes import CategoricalNB
clf = CategoricalNB()

# %%
test_label=test.copy()

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
test_label.iloc[:, 0] = labelencoder.fit_transform(test_label.iloc[:,0])
test_label.iloc[:, 1] = labelencoder.fit_transform(test_label.iloc[:,1])
test_label.iloc[:, 2] = labelencoder.fit_transform(test_label.iloc[:,2])
test_label.iloc[:, 3] = labelencoder.fit_transform(test_label.iloc[:,3])
test_label.iloc[:, 4] = labelencoder.fit_transform(test_label.iloc[:,4])
test_label.iloc[:, 5] = labelencoder.fit_transform(test_label.iloc[:,5])
test_label.iloc[:, 6] = labelencoder.fit_transform(test_label.iloc[:,6])
test_label.iloc[:, 7] = labelencoder.fit_transform(test_label.iloc[:,7])
test_label.iloc[:, 8] = labelencoder.fit_transform(test_label.iloc[:,8])
test_label.iloc[:, 9] = labelencoder.fit_transform(test_label.iloc[:,9])
test_label.iloc[:, 10] = labelencoder.fit_transform(test_label.iloc[:,10])
test_label.iloc[:, 11] = labelencoder.fit_transform(test_label.iloc[:,11])
test_label.iloc[:, 12] = labelencoder.fit_transform(test_label.iloc[:,12])
test_label.iloc[:, 13] = labelencoder.fit_transform(test_label.iloc[:,13])
# Out:
# /var/folders/k4/zgzvg98s73zgn3vhrcp2bhz80000gp/T/ipykernel_3696/2881484004.py:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   test_label.iloc[:, 1] = labelencoder.fit_transform(test_label.iloc[:,1])
# /var/folders/k4/zgzvg98s73zgn3vhrcp2bhz80000gp/T/ipykernel_3696/2881484004.py:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   test_label.iloc[:, 2] = labelencoder.fit_transform(test_label.iloc[:,2])
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
test_label['age'] = labelencoder.fit_transform(test_label['age'])
test_label['workclass'] = labelencoder.fit_transform(test_label['workclass'])
test_label['education'] = labelencoder.fit_transform(test_label['education'])
test_label['educationno'] = labelencoder.fit_transform(test_label['educationno'])
test_label['maritalstatus'] = labelencoder.fit_transform(test_label['maritalstatus'])
test_label['occupation'] = labelencoder.fit_transform(test_label['occupation'])
test_label['relationship'] = labelencoder.fit_transform(test_label['relationship'])
test_label['race'] = labelencoder.fit_transform(test_label['race'])
test_label['sex'] = labelencoder.fit_transform(test_label['sex'])
test_label['capitalgain'] = labelencoder.fit_transform(test_label['capitalgain'])
test_label['capitalloss'] = labelencoder.fit_transform(test_label['capitalloss'])
test_label['hoursperweek'] = labelencoder.fit_transform(test_label['hoursperweek'])
test_label['native'] = labelencoder.fit_transform(test_label['native'])
test_label['Salary'] = labelencoder.fit_transform(test_label['Salary'])

# %%
test_label
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0        8          2          1            6              4           6
# 1       21          2         11            8              2           4
# 2       11          1          7           11              2          10
# 3       27          2         15            9              2           6
# 4       17          2          0            5              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   16          2          9           12              4           9
# 15056   22          2          9           12              0           9
# 15057   21          2          9           12              2           9
# 15058   27          2          9           12              0           0
# 15059   18          3          9           12              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
X=test_label.iloc[:,:-1]
Y=test_label.iloc[:,-1]

# %%
clf.fit(X, Y)
# Out:
# CategoricalNB()

# %%
import numpy as np
X_test=np.array([[8,2,11,6,4,4,3,2,1,87,0,39,37]])
print(clf.predict(X_test))
# Out:
# [0]
# /Users/najeebahamed/anaconda3/lib/python3.10/site-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but CategoricalNB was fitted with feature names
#   warnings.warn(

# %%
clf.predict_proba(X_test)
# Out:
# /Users/najeebahamed/anaconda3/lib/python3.10/site-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but CategoricalNB was fitted with feature names
#   warnings.warn(
# array([[0.99600231, 0.00399769]])
